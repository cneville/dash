# %%
from fredapi import Fred
import pandas as pd
import matplotlib

# %%
fred = Fred()
data = fred.get_series('SP500')

# %%
data
# Out:
# 2013-03-25    1551.69
# 2013-03-26    1563.77
# 2013-03-27    1562.85
# 2013-03-28    1569.19
# 2013-03-29        NaN
#                ...
# 2023-03-20    3951.57
# 2023-03-21    4002.87
# 2023-03-22    3936.97
# 2023-03-23    3948.72
# 2023-03-24    3970.99
# Length: 2610, dtype: float64

# %%
data.plot()
# Out:
# <Axes: >
